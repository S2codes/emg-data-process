# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# df_emg = pd.read_csv("data.csv", sep=",", header=None, skiprows=1).dropna(axis=1, how="all")
df = pd.read_csv("data.csv", sep=",")
# df_emg = df_emg.iloc[:, :-1]
df.head()
# df_emg.describe()
# Out:
#    emg1  emg2  emg3  emg4  emg5    output
# 0   152   152   150   150   150  allclose
# 1   148   148   146   146   144  allclose
# 2   142   140   140   138   136  allclose
# 3   136   136   134   132   132  allclose
# 4   128   128   128   128   128  allclose

# %%
# df.output
# output_values = df['output'].unique()
# output_values

# %%
allclose = df[df.output == 'allclose']
allopen = df[df.output == 'allopen']
index_close = df[df.output == 'index_close']
middle_close = df[df.output == 'middle_close']
ring_close = df[df.output == 'ring_close']
pinky_close = df[df.output == 'pinky_close']

# %%
allclose.emg1.head()
# Out:
# 0    152
# 1    148
# 2    142
# 3    136
# 4    128
# Name: emg1, dtype: int64

# %%
emg1_med = allclose.emg1.median()
emg2_med = allclose.emg2.median()
emg3_med = allclose.emg3.median()
emg4_med = allclose.emg4.median()
emg5_med = allclose.emg5.median()
allclose_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
allclose_medain
# Out:
# [97.0, 96.0, 97.0, 98.0, 98.0]

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(allclose_medain, color="red")
plt.title("all close median")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(allclose.emg1, color="red")
plt.plot(allclose.emg2, color="blue")
plt.plot(allclose.emg3, color="green")
plt.plot(allclose.emg4, color="black")
plt.plot(allclose.emg5, color="yellow")
plt.title("all close")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
allclose.head()
# Out:
#    emg1  emg2  emg3  emg4  emg5    output
# 0   152   152   150   150   150  allclose
# 1   148   148   146   146   144  allclose
# 2   142   140   140   138   136  allclose
# 3   136   136   134   132   132  allclose
# 4   128   128   128   128   128  allclose

# %%
batas1 = 15
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(allopen.emg1, color="red")
plt.plot(allopen.emg2, color="blue")
plt.plot(allopen.emg3, color="green")
plt.plot(allopen.emg4, color="black")
plt.plot(allopen.emg5, color="yellow")
plt.title("all Open")
plt.ylim(bottom=5, top=batas1)
# Out:
# (5.0, 15.0)

# %%
emg1_med = allopen.emg1.median()
emg2_med = allopen.emg2.median()
emg3_med = allopen.emg3.median()
emg4_med = allopen.emg4.median()
emg5_med = allopen.emg5.median()
allopen_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
allopen_medain
# Out:
# [10.0, 10.0, 10.0, 10.0, 10.0]

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(allopen_medain, color="red")
plt.title("all open medain")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(index_close.emg1, color="red")
plt.plot(index_close.emg2, color="blue")
plt.plot(index_close.emg3, color="green")
plt.plot(index_close.emg4, color="black")
plt.plot(index_close.emg5, color="yellow")
plt.title("index close")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
emg1_med = index_close.emg1.median()
emg2_med = index_close.emg2.median()
emg3_med = index_close.emg3.median()
emg4_med = index_close.emg4.median()
emg5_med = index_close.emg5.median()
index_close_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
index_close_medain
# Out:
# [20.0, 20.0, 20.0, 20.0, 20.0]

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(index_close_medain, color="red")
plt.title("index median")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(middle_close.emg1, color="red")
plt.plot(middle_close.emg2, color="blue")
plt.plot(middle_close.emg3, color="green")
plt.plot(middle_close.emg4, color="black")
plt.plot(middle_close.emg5, color="yellow")
plt.title("middle close")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
emg1_med = middle_close.emg1.median()
emg2_med = middle_close.emg2.median()
emg3_med = middle_close.emg3.median()
emg4_med = middle_close.emg4.median()
emg5_med = middle_close.emg5.median()
middle_close_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
middle_close_medain
# Out:
# [26.0, 26.0, 26.0, 26.0, 26.0]

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(middle_close_medain, color="red")
plt.title("middle close median")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(ring_close.emg1, color="red")
plt.plot(ring_close.emg2, color="blue")
plt.plot(ring_close.emg3, color="green")
plt.plot(ring_close.emg4, color="black")
plt.plot(ring_close.emg5, color="yellow")
plt.title("ring close")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
emg1_med = ring_close.emg1.median()
emg2_med = ring_close.emg2.median()
emg3_med = ring_close.emg3.median()
emg4_med = ring_close.emg4.median()
emg5_med = ring_close.emg5.median()
ring_close_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
ring_close_medain
# Out:
# [32.0, 32.0, 32.0, 32.0, 32.0]

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(ring_close_medain, color="red")
plt.title("ring close median")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
batas1 = 150
plt.rcParams["figure.figsize"] = (18,4)
plt.plot(pinky_close.emg1, color="red")
plt.plot(pinky_close.emg2, color="blue")
plt.plot(pinky_close.emg3, color="green")
plt.plot(pinky_close.emg4, color="black")
plt.plot(pinky_close.emg5, color="yellow")
plt.title("Little close")
plt.ylim(bottom=0, top=batas1)
# Out:
# (0.0, 150.0)

# %%
emg1_med = pinky_close.emg1.median()
emg2_med = pinky_close.emg2.median()
emg3_med = pinky_close.emg3.median()
emg4_med = pinky_close.emg4.median()
emg5_med = pinky_close.emg5.median()
pinky_close_medain=[emg1_med, emg2_med, emg3_med, emg4_med, emg5_med]
pinky_close_medain
# Out:
# [16.0, 16.0, 16.0, 16.0, 16.0]
